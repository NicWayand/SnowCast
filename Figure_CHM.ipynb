# %%
# %matplotlib inline
from PIL import Image
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob

# Input Tif dir
tif_dir   = os.path.normpath(r'/home/nwayand/snow_models/output_CHM/SnowCast/output')

# Output png(?) dir
#output_dir = os.path.normpath(r'C:\Users\new356\Model_Output\CHM\SnowCast\Saved')

# Move to Tif dir
os.chdir(tif_dir) 

# Loop though all files
content = glob.glob('*_swe.tif') # Get list of files
num_files = len(content)
print num_files

def plot_swe(df):
    # Plot air temperature
    plt.figure()
    plt.imshow(df)
    plt.clim(-10,25)
    plt.colorbar(ticks=[np.arange(-10, 25,5)])

def plot_air_temp(df):
    # Plot air temperature
    plt.figure()
    plt.imshow(df)
    plt.clim(-10,25)
    plt.colorbar(ticks=[np.arange(-10, 25,5)])

for cfile in content:
    print(cfile)
    im = Image.open(cfile)
    var = np.array(im)
    df = pd.DataFrame(var)
    plot_swe(df)
# Out:
# 48
# SC25_swe.tif
# SC31_swe.tif
# SC36_swe.tif
# SC12_swe.tif
# SC17_swe.tif
# SC39_swe.tif
# SC6_swe.tif
# SC11_swe.tif
# SC46_swe.tif
# SC32_swe.tif
# SC10_swe.tif
# SC28_swe.tif
# SC44_swe.tif
# SC35_swe.tif
# SC41_swe.tif
# SC47_swe.tif
# SC40_swe.tif
# SC8_swe.tif
# SC33_swe.tif
# SC15_swe.tif
# SC9_swe.tif
# /home/nwayand/custom/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# SC34_swe.tif
# SC13_swe.tif
# SC14_swe.tif
# SC16_swe.tif
# SC42_swe.tif
# SC43_swe.tif
# SC26_swe.tif
# SC2_swe.tif
# SC27_swe.tif
# SC23_swe.tif
# SC24_swe.tif
# SC3_swe.tif
# SC21_swe.tif
# SC22_swe.tif
# SC18_swe.tif
# SC30_swe.tif
# SC1_swe.tif
# SC20_swe.tif
# SC4_swe.tif
# SC37_swe.tif
# SC38_swe.tif
# SC5_swe.tif
# SC29_swe.tif
# SC0_swe.tif
# SC45_swe.tif
# SC7_swe.tif
# SC19_swe.tif
